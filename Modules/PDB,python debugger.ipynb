# %% [markdown]
# # PYTHON DEBUGGER

# %% [markdown]
# pdb

# %%
x=[1,2]
y=3

# %%
# x+y
# TypeError: can only concatenate list (not "int") to list

# %%
import pdb # python debugger

# %% [markdown]
# pdb.set_trace()

# %%
help(pdb.set_trace)
# Out:
# Help on function set_trace in module IPython.core.debugger:
#
# set_trace(frame=None)
#     Start debugging from `frame`.
#
#     If frame is not specified, debugging starts from caller's frame.

# %%
x=[1,2]
y=3
pdb.set_trace()
x+y
# Out:
# --Return--
# None
# > <ipython-input-5-321e2d112cb9>(3)<module>()
#       1 x=[1,2]
#       2 y=3
# ----> 3 pdb.set_trace()
#       4 x+y
#
# ipdb> x
# [1, 2]
# ipdb> y
# 3
# ipdb> 1+1
# 2
# ipdb> q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-5-321e2d112cb9> in <module>
#       1 x=[1,2]
#       2 y=3
# ----> 3 pdb.set_trace()
#       4 x+y
#
# C:\Downloads\lib\bdb.py in trace_dispatch(self, frame, event, arg)
#      90             return self.dispatch_call(frame, arg)
#      91         if event == 'return':
# ---> 92             return self.dispatch_return(frame, arg)
#      93         if event == 'exception':
#      94             return self.dispatch_exception(frame, arg)
#
# C:\Downloads\lib\bdb.py in dispatch_return(self, frame, arg)
#     152             finally:
#     153                 self.frame_returning = None
# ...

# %%
help(pdb)
# Out:
# Help on module pdb:
#
# NAME
#     pdb
#
# MODULE REFERENCE
#     https://docs.python.org/3.8/library/pdb
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     The Python Debugger Pdb
# ...
#
#     To use the debugger in its simplest form:
#
#             >>> import pdb
#             >>> pdb.run('<a statement>')
#
#     The debugger's prompt is '(Pdb) '.  This will stop in the first
#     function call in <a statement>.
#
#     Alternatively, if a statement terminated with an unhandled exception,
#     you can use pdb's post-mortem facility to inspect the contents of the
#     traceback:
#
#             >>> <a statement>
#             <exception traceback>
#             >>> import pdb
# ...
