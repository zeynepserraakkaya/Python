# %%
from PIL import Image

# %%
# Python Imaging Library

# %%
python=Image.open("python.png")

# %%
type(python)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
python
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=768x768 at 0x2AF0E1739D0>

# %%
python.size
# Out:
# (768, 768)

# %%
python.filename
# Out:
# 'python.png'

# %%
python.format
# Out:
# 'PNG'

# %%
python.format_description
# Out:
# 'Portable network graphics'

# %%
python.crop((200,200,800,800))
# Out:
# <PIL.Image.Image image mode=RGBA size=600x600 at 0x2AF0E27EEB0>

# %%
python1=python.crop((200,200,800,800))

# %%
python.paste(im=python1,box=(0,0))

# %%
python
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=768x768 at 0x2AF0E1739D0>

# %%
python.paste(im=python1,box=(500,500))

# %%
python
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=768x768 at 0x2AF0E1739D0>

# %%
python.resize((400,400))
# Out:
# <PIL.Image.Image image mode=RGBA size=400x400 at 0x2AF0E2A86A0>

# %%
python.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGBA size=768x768 at 0x2AF0E2A8040>

# %% [markdown]
# RGBA, Red, Green, Blue, Alpha

# %%
red=Image.open("red_color.jpg")

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x2AF0E27EAC0>

# %%
blue=Image.open("blue_color.png")

# %%
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=200x200 at 0x2AF0E2ADC40>

# %%
red.putalpha(0)

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=200x200 at 0x2AF0E27EAC0>

# %%
red.putalpha(255)

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=200x200 at 0x2AF0E27EAC0>

# %%
red.putalpha(128)

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=200x200 at 0x2AF0E27EAC0>
